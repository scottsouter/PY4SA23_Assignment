# %% [markdown]
# # Lab Assignment 2 - Scott Souter

# %% [markdown]
# ## Student ID - 200017121

# %% [markdown]
# #### GitHub Repository URL: https://github.com/scottsouter/PY4SA23_Assignment

# %% [markdown]
# ## Python Basics

# %% [markdown]
# **Task 1: Create an If...Else statement that will test whether a number is divisible by three. "YOUR VALUE is divisible by 3" should be printed if the value is divisible by three. "YOUR VALUE is not divisible by three" should be printed if it is not divisible by three. Test the statement on a numeric variable. Upper case text in the print statement should be replaced with the tested number.**

# %%
x = input("What is your input?") 

if float (x) %3 == 0:
    print(str(x) + " is divisible by 3.")
else:
    print(str(x) + " is not divisible by 3.")
# Out:
# What is your input? 5
# 5 is not divisible by 3.

# %% [markdown]
# I' used the input function allowing a value designated as 'x' to be entered. Using '%3 == 0' and the 'if' and 'else' statements, if the whole number can be divided by 3 to return a whole number the ('x' is divisible by 3) will be returned. Otherwise, ('x' is not divisible by 3 will be returned. the float function allows the string value to be converted to a float so it can work with the function '%3 == 0'

# %% [markdown]
# **T2: Create an If...Else statement that will test whether a type of fruit, represented as a text string, is in a list of acceptable fruits (apple, orange, pear, kiwi, or strawberry). If the fruit is on the list, the following should be printed: "YOUR FRUIT is acceptable." If not, then the following should be printed: "YOUR FRUIT is not acceptable." Upper case text in the print statement should be replaced with the tested fruit.**

# %%
fruit_list = ['apple', 'orange', 'pear', 'kiwi', 'strawberry']

fruit = (input('Enter the fruit you want to select:'))

if fruit in fruit_list:
    print('fruit is acceptable')
else:
    print('fruit is not acceptable')
# Out:
# Enter the fruit you want to select: apple
# fruit is acceptable

# %% [markdown]
# I have created a list containing different fruits and also used the input function allowing a fruit to be selected. Using the 'if' and 'else' statements, if the fruit selected is in the fruit_list then (fruit is acceptable) will be returned. Otherwise, (fruit is not acceptable) will be returned.

# %% [markdown]
# **T3: Create a function to calculate the distance between two coordinates using the haversine formula. Write the following formula where the input parameters are a pair of coordinates as two lists.**

# %%
lon1 = input("Enter the longitiude of origin")
lat1 = input("Enter the latitiude of origin")
lon2 = input("Enter the longitiude of destination")
lat2 = input("Enter the latitude of destination")

from math import radians, cos, sin, asin, sqrt

def haversine(lon1, lat1, lon2, lat2):
    
    R = 6371
    
    dlat = radians(float(lat2) - float(lat1))
    dlon = radians(float(lon2) - float(lon1))
    lat1 = radians(float(lat1))
    lat2 = radians(float(lat2))
    
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a))
    
    return R * c

Answer = (haversine(lat1, lon1, lat2, lon2))

print("The distance between these two points is " + str(Answer) + " kilometres.")
# Out:
# Enter the longitiude of origin 2
# Enter the latitiude of origin 3
# Enter the longitiude of destination 4
# Enter the latitude of destination 5
# The distance between these two points is 314.28325507368385 kilometres.

# %%
import numpy as np

from math import *

#import latitude and longitude for coordinate 1
coordinate1 = [lat1, lon1]
coordinate1[0]=(float(input("Enter the latitude of your first coordinate:")))

#import longitude for cooridnate 1  
coordinate1[1]=(float(input("Enter the longitude of your first coordinate:")))

#import latitude and longitiude for cooridnate 2  
coordinate2 = [lat2, lon2]
coordinate2[0]=(float(input("Enter the latitude of your first coordinate:"))) #float turns the string into a number

#import longitude for cooridnate 2 
coordinate2[1]=(float(input("Enter the longitude of your first coordinate:")))

def haversine(coordinate1, coordinate2):
    
    coordinate1, coordinate2 = np.radians([coordinate1, coordinate2]) #converting a degree value into radians
    
    a = sin((coordinate2[0]-coordinate1[0])/2)**2 + cos(coordinate1[0]) * cos(coordinate2[0]) * sin((coordinate2[1]-coordinate1[1])/2)**2
    c = 2 * asin(sqrt(a))
                                                                                                                                
    return 6371 * c
                                                                                                                                
d=(haversine(coordinate1, coordinate2))
                                                                                                                            
print("The distance between the two coordinates is:", d,"km")
# Out:
# Enter the latitude of your first coordinate: 12
# Enter the longitude of your first coordinate: 324
# Enter the latitude of your first coordinate: 11
# Enter the longitude of your first coordinate: 311
# The distance between the two coordinates is: 1420.7309966249925 km

# %% [markdown]
# Firstly I imported numpy as np and, from math imported '*'. I used the 'input' function to allow values of latitude and longitude to be entered for both coordinates so the distance between these points can be measured. these points are labelled 'lon1','lat1','lon2','lat2'. I used 'float' to convert real numbers or intigers into floats. I used the haversine formula to calculate the distance between the two coordinates. The value '6371' is the radius in 'km' which is multiplied by 'c' which is calcultaed using 'a'Finally, I printed 'The distance between the two coordinates is' using the 'print' formula which is the two coordinates multiplies by haversine.

# %% [markdown]
# ## Pandas and NumPy

# %% [markdown]
# **Question 1: How many trees are of the Quercus or Acer genus?**

# %%
import numpy as np #importing numpy
import pandas as pd #importing pandas

park_trees_df = pd.read_csv('portland_park_trees.csv') #reading in the data
subQuerusAcer = park_trees_df[(park_trees_df["Genus"]=="Quercus") + (park_trees_df["Genus"]=="Acer")] #sub-setting the Genus to Querus and Acer
print(len(subQuerusAcer)) #printing subset
# Out:
# 5675

# %% [markdown]
# Firstly, I imported numpy as np and imported pandas as pd. To see how many trees were of the Quercus or Acer genus i first read in the data file 'portland_park_trees.csv' and called it 'park_trees_df'. I then created a subset of this data file called 'subQuercusAcer' which contained only trees from the Quercus and Acer genus. I then used the 'len' function to find out how many trees were within the subset. I used the '.print' function to show this.

# %% [markdown]
# **Q2: How many trees are of the Quercus or Acer genus and have a DBH larger than 50 inches?**

# %%
QuAcfifty = subQuerusAcer[subQuerusAcer["DBH"]>50] #creating a sub-set where Querus and Acer trees have a DBH of over 50 inches
print("There are", len(QuAcfifty),"trees of the Quercus or Acer genus that have a DBH larger than 50 inches")
# Out:
# There are 124 trees of the Quercus or Acer genus that have a DBH larger than 50 inches

# %% [markdown]
# To find out how many trees of the Quercus and Acer genus have a DBH which is larger than 50 inches I created a subset called QuAcfifty. Within this subset the subset 'subQuercusAcer' was filtered so that only trees which had a larger DBH than 50 appeared. I then printed this using the '.print' function

# %% [markdown]
# **Q3: Which genus has the highest mean DBH of the following genera: Quercus, Acer, or Fraxinus?**

# %%
Genus_list = ['Quercus', 'Acer', 'Fraxinus']
df = park_trees_df.loc[park_trees_df['Genus'].isin(Genus_list)]
                  
genus_mean = df.groupby('Genus')['DBH'].mean()
greatest_mean = genus_mean.idxmax()
print("The genus with the greatest mean DBH is", greatest_mean)
# Out:
# The genus with the greatest mean DBH is Quercus

# %% [markdown]
# Firstly, I created a list of Quercus, Acer and Fraxinus by creating 'Genus_list'. I then created a subset which contained only the 'Genus' column for those genus in the 'Genus_list'. Then I grouped the rows by unique values in the 'Genus' column and calculated the mean. Using '.idxmax' I then found the greatest mean and printed this value using 'print'.

# %%
tree_data = pd.DataFrame()
tree_data["Mean"] = park_trees_df.groupby("Genus")["DBH"].mean()
tree_data
# Out:
#                     Mean
# Genus
# Abies          20.281169
# Acer           18.419085
# Aesculus       28.691304
# Ailanthus      16.978571
# Albizia         7.340000
# ...                  ...
# Unknown        11.195833
# Viburnum        8.300000
# Xanthocyparis   5.051852
# Zelkova        11.480769
# x              15.200000
#
# [117 rows x 1 columns]

# %% [markdown]
# * Quercus has the highest mean DBH

# %% [markdown]
# **Q4: How many different species of trees are recorded in the Acer genus?**

# %%
Species_tree = (park_trees_df[["Species", "Genus"]])
Species_tree
AcerSpecies = Species_tree[(Species_tree["Genus"]=="Acer")]
AcerSpecies
print("There are", len(AcerSpecies["Species"].unique()), "different species of trees recorded in the Acer genus")
# Out:
# There are 20 different species of trees recorded in the Acer genus

# %% [markdown]
# I have made a subset that just contains "Species" and "Genus" called 'Species_tree'. I have then made a second subset which just contains the Genus, Acer called AcerSpecies. I finally printed how many different species of tree there are in the Acer Genus using the AcerSpecies subset. I did this using the 'len' and '.unique' functions.

# %% [markdown]
# **Question 5**

# %% [markdown]
# **Calculate a new column named "pop_M" (population in millions), by transforming the "pop" (population) column.**

# %%
cities_df = pd.read_csv('world_cities.csv') #reading in the data

# %% [markdown]
# I read in the dataset 'world_cities.csv' by using the '.read_csv' function and called this 'cities_df'

# %%
cities_df["pop_M"] = cities_df["pop"] / 1000000 # creating new column pop_M
cities_df #printing the data
# Out:
#                      city       country     pop    lat    lon  capital  \
# 0      'Abasan al-Jadidah     Palestine    5629  31.31  34.34        0
# 1      'Abasan al-Kabirah     Palestine   18999  31.32  34.35        0
# 2            'Abdul Hakim      Pakistan   47788  30.55  72.11        0
# 3      'Abdullah-as-Salam        Kuwait   21817  29.36  47.98        0
# 4                   'Abud     Palestine    2456  32.03  35.07        0
# ...                   ...           ...     ...    ...    ...      ...
# 43640           az-Zubayr          Iraq  124611  30.39  47.71        0
# 43641            az-Zulfi  Saudi Arabia   54070  26.30  44.80        0
# 43642       az-Zuwaytinah         Libya   21984  30.95  20.12        0
# 43643        s-Gravenhage   Netherlands  479525  52.07   4.30        0
# 43644     s-Hertogenbosch   Netherlands  135529  51.68   5.30        0
#
#           pop_M
# 0      0.005629
# 1      0.018999
# 2      0.047788
# 3      0.021817
# 4      0.002456
# ...

# %% [markdown]
# I used the data stored in the 'pop' column to create a new column called 'pop_M' which derives from the function (pop_M = pop / 1000000) giving the population value by the million. I then printed the new 'cities_df' to get the 'pop_M' column

# %% [markdown]
# **Remove the original "pop" column.**

# %%
#creating a subset to remove original 'pop' column
subset_query = cities_df.query("pop_M > 0")[["city", "country", "lat", "lon", "capital", "pop_M"]] 
subset_query #printing new subset
# Out:
#                      city       country    lat    lon  capital     pop_M
# 0      'Abasan al-Jadidah     Palestine  31.31  34.34        0  0.005629
# 1      'Abasan al-Kabirah     Palestine  31.32  34.35        0  0.018999
# 2            'Abdul Hakim      Pakistan  30.55  72.11        0  0.047788
# 3      'Abdullah-as-Salam        Kuwait  29.36  47.98        0  0.021817
# 4                   'Abud     Palestine  32.03  35.07        0  0.002456
# ...                   ...           ...    ...    ...      ...       ...
# 43640           az-Zubayr          Iraq  30.39  47.71        0  0.124611
# 43641            az-Zulfi  Saudi Arabia  26.30  44.80        0  0.054070
# 43642       az-Zuwaytinah         Libya  30.95  20.12        0  0.021984
# 43643        s-Gravenhage   Netherlands  52.07   4.30        0  0.479525
# 43644     s-Hertogenbosch   Netherlands  51.68   5.30        0  0.135529
#
# [43628 rows x 6 columns]

# %% [markdown]
# To remove the original 'pop' column I created a new subset called 'subset_query'. Within this subset I made a new dataset in which all values of the 'pop_M' were above 0, but I have also sub-setted this include everything apart from the original 'pop' column. I then printed this new subset 'subset_query'

# %% [markdown]
# **Choose/subset a city that starts with the same letter as your first name (for example, "Mexico City" if your first name is Michael).**

# %%
#creating a subset of cities starting with letter 'S' using startwith function
subset_query[subset_query["city"].str.startswith("S")]
# Out:
#                       city            country    lat     lon  capital  \
# 27919  San Antonio de Pale  Equatorial Guinea  -1.41    5.61        0
# 31942               Sa Dec            Vietnam  10.30  105.76        0
# 31943              Sa Kaeo           Thailand  13.82  102.07        0
# 31944              Sa'abat            Algeria  36.63    3.70        0
# 31945              Sa'idah            Algeria  34.84    0.14        0
# ...                    ...                ...    ...     ...      ...
# 36897            Szprotawa             Poland  51.57   15.52        0
# 36898                Sztum             Poland  53.85   18.96        0
# 36899               Szubin             Poland  53.01   17.72        0
# 36900       Szurdokpuspoki            Hungary  47.86   19.70        0
# 36901           Szydlowiec             Poland  51.23   20.86        0
#
#           pop_M
# 27919  0.004279
# 31942  0.061430
# 31943  0.029821
# 31944  0.019440
# 31945  0.129821
# ...         ...
# ...

# %% [markdown]
# To create a subset of cities that starts with the same latter as my firstname I used the new subset 'subset_query' and filtered this subset so that only cities startign with the letter 'S' appeared. I did this by using '.str.startswith'.

# %% [markdown]
# **Subset the five biggest (i.e., largest population sizes) cities from the country where your selected city is.**

# %%
Poland_subset = subset_query[subset_query["country"] == "Poland"] #creating a country subset of just Poland
Poland_subset #printing this subset

Poland_pop = Poland_subset.sort_values(by="pop_M").tail() #printing the 5 largest population sizes using the tail fucntion

# %% [markdown]
# To select the five biggest populations in a city from Poland I first created a new subset 'Poland_subset' and filtered the subset 'subset_query' inside of this subset to only contain the country Poland. I then created a second subset 'Poland_pop' and within this subset, it was filtered that the previous subset created 'Poland_subset' only contained the cities with the five largest populations. This was done by using '.sort values' and '.tail'.

# %% [markdown]
# **Print the result**

# %%
Poland_pop #printing this subset
# Out:
#           city country    lat    lon  capital     pop_M
# 29756   Poznan  Poland  52.40  16.90        0  0.567957
# 41895  Wroclaw  Poland  51.11  17.03        0  0.633276
# 8382    Cracow  Poland  50.06  19.96        0  0.753829
# 21253     Lodz  Poland  51.77  19.46        0  0.762615
# 41441   Warsaw  Poland  52.26  21.02        1  1.634441

# %% [markdown]
# I then printed this reuslt by typing 'Poland_pop'

# %%
#creating new subset of the 5 largest cities by population in Poland
Poland_fivebiggest = Poland_pop[Poland_pop["pop_M"]>0.567956] 
#printing this subset
Poland_fivebiggest
# Out:
#           city country    lat    lon  capital     pop_M
# 29756   Poznan  Poland  52.40  16.90        0  0.567957
# 41895  Wroclaw  Poland  51.11  17.03        0  0.633276
# 8382    Cracow  Poland  50.06  19.96        0  0.753829
# 21253     Lodz  Poland  51.77  19.46        0  0.762615
# 41441   Warsaw  Poland  52.26  21.02        1  1.634441

# %% [markdown]
# ## Python Data Visualization

# %% [markdown]
# **Graph 1: Create a scatterplot for just trees in the Ulmus genus with DBH mapped to the x-axis and tree height mapped to the y-axis (Hint: You will need to use the “Genus”, “DBH”, and “TreeHeight” attributes.).**

# %%
#impprting mathplot
import matplotlib.pyplot as plt
#importing seaborn
import seaborn as sns 
#creating scatterplot of trees in Ulmus genus
sns.scatterplot(data=park_trees_df.loc[park_trees_df["Genus"]=="Ulmus"], x='DBH', y='TreeHeight')
# Out:
# <AxesSubplot: xlabel='DBH', ylabel='TreeHeight'>

# %% [markdown]
# I imported mathplotlib and seaborn. I then created a scatterplot using the loc methods for just trees in the Ulmus genus with DBH on the x axis and tree height on the y axis. I did this by using the '.scatterplot' function.

# %% [markdown]
# **G2: Create a scatterplot for just trees in the Ulmus genus with DBH mapped to the x-axis, tree height mapped to the y-axis, and tree species mapped to hue (Hint: You will need to use the “Genus”, “Genus_spec”, “DBH”, and “TreeHeight” attributes.)**

# %%
#creating scatterplot of trees in Ulmus genus
sns.scatterplot(data=park_trees_df.loc[park_trees_df["Genus"]=="Ulmus"], x='DBH', y='TreeHeight', hue='Genus_spec')
# Out:
# <AxesSubplot: xlabel='DBH', ylabel='TreeHeight'>

# %% [markdown]
# I created a scatterplot using the loc methods for just trees in the Ulmus genus with DBH on the x axis and tree height on the y axis and I also added a third variable, tree species, mapped to hue. I did this by using the '.scatterplot' function.

# %% [markdown]
# **G3: Create a boxplot of DBH for just the Ulmus genus differentiated by species (or, each species should have its own boxplot).**

# %%
#setting plot bounds
plt.figure(figsize=(6, 5))
#creating boxplot of DBH for just the Ulmus Genus
sns.boxplot(data=park_trees_df.loc[park_trees_df["Genus"]=="Ulmus"], x='DBH', y='Genus_spec') 
#setting a title for the boxplot
plt.title('Box Plot') 
#printing the boxlot
plt.show()

# %% [markdown]
# I firstly set the plot bounds for the boxplot. I then created a boxplot, using the loc method, of DBH for just the Ulmus genus using the '.boxplot' function. I then added a title to the boxplot using the '.title' function and then printed this boxplot by using the 'plt.show()' function

# %% [markdown]
# **G4: Combine Graphs 1 and 3 into a single figure. Do not plot a legend for any of the graphs.**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#creating a figure with two sub-plots beside each other
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 8))

#plotting boxplot the left subplot
sns.boxplot(data=park_trees_df.loc[park_trees_df["Genus"]=="Ulmus"], x='DBH', y='Genus_spec', ax=ax1)
ax1.set_title('Box plot of DBH for species within Ulmus Genus')          
    
#plotting scatterplot the right subplot
sns.scatterplot(data=park_trees_df.loc[park_trees_df["Genus"]=="Ulmus"], x='DBH', y='TreeHeight', ax=ax2)
ax2.set_title('Scatterplot of the data')

#print sub-plots
plt.show()

# %% [markdown]
# To combine graphs 1 and 3 into a single figure I firstly designated the number of subplot columns to 2 using the 'ncols=2' function. I then created a figure with two sub-plots beside each other (ax1 and ax2) by using the '.subplots' function. Next I plotted the boxplot created above to the left side of the subplot (ax1) and set a title to this by using the '.set_title' function. I then plotted the scatterplot created above to the right side of the subplot (ax2) and set a title to this by using the '.set_title' function. Finally I printed these graphs combined into one figure using the 'plt.show' function

# %% [markdown]
# ## Python GeoPandas

# %%
import geopandas as gpd #importing geopandas
import pandas as pd #importing pandas

# %% [markdown]
# I imported geopandas as gpd and imported pandas as pd

# %% [markdown]
# **Task 1: Read the selected dataset as GeoPandas DataFrame**

# %%
ferry_geo = gpd.read_file('SG_FerryPorts_2021/SG_FerryPorts_2021.shp') #reading in FerryPorts file

# %% [markdown]
# I read in the 'SG_FerryPorts_2021.shp' file from the Spatial Data portal of Scotland which shows the passenger and vehicle ferry ports in Scotland and called this 'ferry_geo'

# %% [markdown]
# **T2: Use the correct code to plot the first 5 and the last 5 sets of records in your selected dataset.**

# %%
ferry_geo.plot() #plotting the FerryPorts dataset
# Out:
# <AxesSubplot: >

# %% [markdown]
# I plotted the 'SG_FerryPorts_2021.shp' file using the '.plot' function

# %%
ferry_geo #plotting the first and last 5 sets of records for FerryPorts dataset
# Out:
#     PortCode           PortName        LocalAutho      MarineRegi  ServiceTyp  \
# 0        NaN         Anstruther              Fife   Forth and Tay  Commercial
# 1        NaN        Isle of May              Fife   Forth and Tay  Commercial
# 2        NaN  Raasay (Suisnish)          Highland  West Highlands    Lifeline
# 3        NaN              Larne     International             NaN  Commercial
# 4        NaN        Ballycastle     International             NaN  Commercial
# ..       ...                ...               ...             ...         ...
# 202      WBU    West Burrafirth  Shetland Islands  Shetland Isles    Lifeline
# 203      WLS              Walls  Shetland Islands  Shetland Isles    Lifeline
# 204      WMB         Wemyss Bay        Inverclyde           Clyde    Lifeline
# 205      WYR               Wyre    Orkney Islands  Orkney Islands    Lifeline
# 206      YOK              Yoker      Glasgow City           Clyde    Lifeline
#
# ...

# %% [markdown]
# I plotted the first 5 and last 5 sets of records for the 'SG_FerryPorts_2021.shp' dataset by typing in the dataset (ferry_geo) I had created when i read in the 'SG_FerryPorts_2021.shp' file

# %% [markdown]
# **T3. Create a map where you can explore the selected dataset. Try to plot the map using some categorical attribute. Include a ToolTip.**

# %%
ferry_geo.explore(column='PortName', cmap='RdYlBu', legend = False) #plotting a map using categorical attribute using explore method
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# I created a map where you can explore the Ferry Ports dataset (ferry_geo) by using the '.explore' function. I selected a suitable column to explore using the 'column=' function, in this case 'PortName'. I also selected a suitable colour for the map using the 'cmap=' function. I removed the legend because it was too big.

# %% [markdown]
# **T4. What is the Coordinate Reference System of the selected dataset?**

# %%
print(ferry_geo.crs)
# Out:
# EPSG:27700

# %% [markdown]
# I found out the Coordinate Refernce System of the selected data set by placing the '.crs' function after the name of the selected data set ('ferry_geo'). I used 'print' to show the CRS of this selected dataset.

# %% [markdown]
# **T5. How many features does the selected dataset contain?**

# %%
print(len(ferry_geo))
# Out:
# 207

# %% [markdown]
# To find out how many features the dataset 'ferry_geo' contains I used the 'len' function to identify the length

# %% [markdown]
# **T6. Define a sub-setting criterion to create a new geopandas dataframe where you filter the selected dataset based on a categorical attribute.**

# %%
cat_ferry_geo = ferry_geo[ferry_geo["PortName"]=="Walls"] #creating a sub-set by filtering the PortName to just 'Walls'
cat_ferry_geo #printing this subset
# Out:
#     PortCode PortName        LocalAutho      MarineRegi ServiceTyp  Status  \
# 203      WLS    Walls  Shetland Islands  Shetland Isles   Lifeline  Active
#
#      ZElev                                geometry
# 203      0  POINT Z (423966.216 1148924.330 0.000)

# %% [markdown]
# I defined a sub-set criterion 'cat_ferry_geo' to create a new geopandas dataframe where I filtered the selcted dataset 'ferry_geo' based on the categorical variable 'PortName' to just 'Walls'. I then printed this subset 'cat_ferry_geo'

# %% [markdown]
# **T7. Define a sub-setting criterion to create a new geopandas dataframe where you filter the selected dataset based on a numerical attribute.**

# %%
num_ferry_geo = ferry_geo[ferry_geo["ZElev"] >= 0] #creating a sub-set by filtering the ZElev to greater than 0
num_ferry_geo #printing this subset
# Out:
#     PortCode           PortName        LocalAutho      MarineRegi  ServiceTyp  \
# 0        NaN         Anstruther              Fife   Forth and Tay  Commercial
# 1        NaN        Isle of May              Fife   Forth and Tay  Commercial
# 2        NaN  Raasay (Suisnish)          Highland  West Highlands    Lifeline
# 3        NaN              Larne     International             NaN  Commercial
# 4        NaN        Ballycastle     International             NaN  Commercial
# ..       ...                ...               ...             ...         ...
# 202      WBU    West Burrafirth  Shetland Islands  Shetland Isles    Lifeline
# 203      WLS              Walls  Shetland Islands  Shetland Isles    Lifeline
# 204      WMB         Wemyss Bay        Inverclyde           Clyde    Lifeline
# 205      WYR               Wyre    Orkney Islands  Orkney Islands    Lifeline
# 206      YOK              Yoker      Glasgow City           Clyde    Lifeline
#
# ...

# %% [markdown]
# I defined a sub-set criterion 'num_ferry_geo' to create a new geopandas dataframe where I filtered the selcted dataset 'ferry_geo' based on the numerical variable 'ZElev' to '>=0'. I then printed this subset 'num_ferry_geo'

# %% [markdown]
# **T8. Plot the new/filtered geopandas dataframe using one of the attributes to create a choropleth map.**

# %%
#plotting the dataframe to a chlorepleth map using the catergorical attribute using the plot fucntion 
num_ferry_geo.plot(column='ZElev' ,cmap='RdYlBu')
# Out:
# <AxesSubplot: >

# %% [markdown]
# I plotted the new numerical geopandas dataframe using the '.plot' function on the new dataframe to create a chlorepleth map. Within this '.plot' function I used 'column' to select the appropriate column 'ZElev' and I also selected a suitbale colour for this map using the 'cmap' function. I also had to remove the legend from this chlorepleth map as it was too big.

# %% [markdown]
# ## Python Rasterrio

# %%
import rasterio as rio #importing raterio as rio
from rasterio import plot #importing rasterio import plot

# %% [markdown]
# I imported rasterio as rio, also, from rasterio I imported plot.

# %% [markdown]
# **Task 1. Read the file as a rasterio dataset**

# %%
# reading the file as a rasterio dataset
elev_geo = rio.open('elev.tif')
elev_array = elev_geo.read(1)
elev_array
# Out:
# array([[-32768, -32768, -32768, ..., -32768, -32768, -32768],
#        [-32768, -32768, -32768, ..., -32768, -32768, -32768],
#        [-32768, -32768, -32768, ..., -32768, -32768, -32768],
#        ...,
#        [-32768, -32768, -32768, ..., -32768, -32768, -32768],
#        [-32768, -32768, -32768, ..., -32768, -32768, -32768],
#        [-32768, -32768, -32768, ..., -32768, -32768, -32768]], dtype=int16)

# %% [markdown]
# Using rio.open I opened the 'elev.tif' file and called it 'elev_geo'. I read the file using the '.read' method coinciding with the array function to produce the array which shows the elevation vlaues.
#
# I then created an array called 'elev_array' and read 'elev_geo' using the '.read' method. I finally printed the elev_array.

# %% [markdown]
# **T2: What is the CRS of the dataset?**

# %%
print(elev_geo.crs)
# Out:
# EPSG:32617

# %% [markdown]
# To find out the CRS of the dataset I placed the '.crs' function after the data set 'elev_geo'. I printed this using the 'print' function

# %% [markdown]
# **T3: Describe the raster dataset regarding the raster extent (bounds), the reference system, and how many bands are in this dataset.**

# %%
print(elev_geo.bounds)
print(elev_geo.crs)
print(elev_geo.count)
# Out:
# BoundingBox(left=479753.39945587853, bottom=4170823.2037591375, right=668843.3994558785, top=4347733.203759138)
# EPSG:32617
# 1

# %% [markdown]
# I described the raster dataset regarding the raster extent (bounds) by using the '.bounds' function on the elev_geo dataset. I showed this by using the '.print' function.
# I described the raster dataset regarding the reference system (crs) by using the '.crs' function on the elev_geo dataset. I showed this by using the '.print' function.
# I described the raster dataset regarding how many bands were in the dataset (count) by using the '.count' function on the elev_geo dataset. I showed this by using the '.print' function.

# %% [markdown]
# **T4: Create a plot/map of the raster dataset.**

# %%
rasterio_read_masked = np.ma.masked_array(elev_array, mask=(elev_array == -32768))
rasterio_read_masked

#display masked raster using the gist_grey colour 
plt.rcParams['figure.figsize'] = [10, 8]
plt.imshow(rasterio_read_masked, cmap="gist_earth")

# %% [markdown]
# **T5: Create Histograms from the raster.**

# %% [markdown]
# I have firstly masked the raster data and called this 'rasterio_read_masked'. I set the figure size at [10, 8] using '.rcParams' and then using the 'imshow' method I have mapped the raster data.

# %%
from rasterio.plot import show_hist

#creating histogram of 50 bins using show_hist with the set paramters 
show_hist(rasterio_read_masked, bins=50, lw=0.0, stacked=False, alpha = 0.3,
         histtype='stepfilled', title='Histogram')

# %% [markdown]
# I firstly imported the 'show_hist' function from rasterio.plot. I then used the 'show_hist' function to create a histogram highlighting the changes of frequency in elevation. I set the number of bins to be 50, set the 'histtype'='stepfilled and set the 'title'='Histogram'.
